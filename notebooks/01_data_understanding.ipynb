# %% [markdown]
# # 01 — Data Understanding
#
# **Goal:** Load the raw datasets, inspect their structure, and document key properties before any cleaning takes place.
#
# **Outputs:** Notes in this notebook; entries in `docs/dataset_inventory.md`.
#
# ---

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

# Add src/ to path so we can import project modules
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.utils import data_path, read_csv_safe

print('Setup complete.')

# %% [markdown]
# ## 1. EIGE Gender Equality Index
#
# **TODO:** Replace the placeholder filepath with the actual file name once the data is downloaded.

# %%
# eige_raw = read_csv_safe(data_path('raw', 'eige_gender_equality_index.csv'))
# eige_raw.head()

# %%
# print(eige_raw.shape)
# print(eige_raw.dtypes)
# print(eige_raw.isnull().sum())

# %% [markdown]
# ## 2. Eurostat Prison Statistics
#
# **TODO:** Replace the placeholder filepath with the actual file name once the data is downloaded.

# %%
# eurostat_raw = read_csv_safe(data_path('raw', 'eurostat_prison_statistics.csv'))
# eurostat_raw.head()

# %%
# print(eurostat_raw.shape)
# print(eurostat_raw.dtypes)
# print(eurostat_raw.isnull().sum())

# %% [markdown]
# ## 3. Key Observations & Open Questions
#
# _Use this cell to record your findings and any open questions for the team._
#
# - ...
# - ...
