# %% [markdown]
# # 03 — Exploratory Data Analysis
#
# **Goal:** Summarise the merged dataset, identify distributions, correlations, outliers, and regional patterns.
#
# **Input:** `data/processed/merged_dataset.csv`
# **Outputs:** Summary tables and insights documented in this notebook.
#
# ---

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.utils import data_path, read_csv_safe
from src.eda import describe_dataset, missing_values_report, correlation_matrix

# %matplotlib inline
sns.set_theme(style='whitegrid', palette='muted')

print('Setup complete.')

# %% [markdown]
# ## 1. Load Processed Data

# %%
# df = read_csv_safe(data_path('processed', 'merged_dataset.csv'))
# df.head()

# %% [markdown]
# ## 2. Descriptive Statistics

# %%
# describe_dataset(df)

# %%
# missing_values_report(df)

# %% [markdown]
# ## 3. Distribution of Key Variables

# %%
# fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# df['gei_score'].hist(ax=axes[0], bins=20)
# axes[0].set_title('Distribution of GEI Score')
# df['female_share_pct'].hist(ax=axes[1], bins=20, color='salmon')
# axes[1].set_title('Distribution of Female Prisoner Share (%)')
# plt.tight_layout()

# %% [markdown]
# ## 4. Correlation Analysis

# %%
# corr = correlation_matrix(df, columns=['gei_score', 'female_share_pct'])
# sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
# plt.title('Correlation matrix')
# plt.tight_layout()

# %% [markdown]
# ## 5. Regional Patterns

# %%
# df.groupby('region')[['gei_score', 'female_share_pct']].mean().round(2)

# %% [markdown]
# ## 6. Key Findings
#
# _Summarise your main findings here. These will feed into the report and presentation._
#
# - ...
# - ...
